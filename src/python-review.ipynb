# %% [markdown]
# # Python Quick Review Tutorial
#
# Python is a powerful, high-level programming language known for its readability and versatility. This quick review covers essential Python concepts, including variables, data types, control structures, functions, and basic object-oriented programming. Each section includes examples, exercises, and solutions to reinforce your understanding.

# %% [raw]
# ## 1. Basic Concepts
#
# ### 1.1 Variables and Data Types
#
# In Python, you can define variables and assign values without specifying the data type. Common data types include integers, floats, strings, and booleans.

# %%
# Variable assignment
a = 10          # Integer
b = 20.5        # Float
name = "Alice"  # String
is_active = True  # Boolean

print(a, b, name, is_active)
# Out:
# 10 20.5 Alice True
